# %% [markdown]
# # Inference test 1 images

# %%
from inference import LungSegmentation

# %%
segments = LungSegmentation(checkpoint_path = "checkpoint/SE_checkpoint_889", device="cpu", threshold = 0.1)

# %%
import matplotlib.pyplot as plt
img_array = plt.imread("images/7aa6611b60c2e6115fdcdb7194e1f2_jumbo.jpg")
predict = segments.predict(img_array)
segments.visualize(img_array, predict)

# %%
import matplotlib.pyplot as plt
img_array = plt.imread("images\8d467195db13702b0d4b53c502cbc1_jumbo.jpg")
predict = segments.predict(img_array)
segments.visualize(img_array, predict)

# %%
import matplotlib.pyplot as plt
img_array = plt.imread("images/5662ee814c0f5d5739526217a9b434_jumbo.jpeg")
predict = segments.predict(img_array)
segments.visualize(img_array, predict)

# %%
import matplotlib.pyplot as plt
img_array = plt.imread("images\d7b4ad69e5bc6685a767bf9c7f4239_jumbo.jpeg")
predict = segments.predict(img_array)
segments.visualize(img_array, predict)
