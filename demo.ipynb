# %% [markdown]
# # Inference test 1 images

# %%
from inference import LungSegmentation

# %%
segments = LungSegmentation(checkpoint_path = "checkpoint/SE_checkpoint_889", device="cpu", threshold = 0.5)

# %%
import matplotlib.pyplot as plt
import numpy as np
img_array = plt.imread("images/test_2203.jpg")
# img_array = np.concat(np.array((3))
print(img_array.shape)
# img_array = img_array[:, :,0:1]

# img_array = (img_array*255).astype(np.uint8)
predict = segments.predict(img_array)
print(predict.shape)
segments.visualize(img_array, predict)
# plt.imshow(predict)
# plt.show()
# Out:
# (1024, 1171, 3)
# (1024, 1171)

# %%
import matplotlib.pyplot as plt
import numpy as np
img_array = plt.imread("images/test_1703 (2).jpg")
print(img_array.shape)
# img_array = (img_array*255).astype(np.uint8)
predict = segments.predict(img_array)
segments.visualize(img_array, predict)
# plt.imshow(predict)
# plt.show()
# Out:
# (886, 760, 3)
# C:\Users\Admin\anaconda3\envs\segmentation\lib\site-packages\torchvision\transforms\functional.py:74: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:141.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# > e:\vinbrain-internship\lungsegment\inference.py(81)visualize()
#      79         color_mask = np.transpose(color_mask, (1,2,0))
#      80         import pdb; pdb.set_trace()
# ---> 81         blend = 0.3*color_mask + 0.7*img*mask + (1 - mask)*img
#      82         plt.figure(figsize=(10,10))
#      83         plt.imshow(blend)
#
# ipdb> img.shape
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
img_array = plt.imread("images/test_1703 (3).jpg")
# img_array = (img_array*255).astype(np.uint8)
predict = segments.predict(img_array)
segments.visualize(img_array, predict)
# plt.imshow(predict)
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
img_array = plt.imread("images/test_1703 (4).jpg")
# img_array = (img_array*255).astype(np.uint8)
predict = segments.predict(img_array)
segments.visualize(img_array, predict)
# plt.imshow(predict)
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
img_array = plt.imread("images/test_1703 (5).jpg")
# img_array = (img_array*255).astype(np.uint8)
predict = segments.predict(img_array)
segments.visualize(img_array, predict)
# plt.imshow(predict)
# plt.show()
